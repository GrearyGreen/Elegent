# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = 12, 9  # 设置figure_size尺寸
plt.rcParams['font.sans-serif'] = ['SimHei']  # 图表可输出中文
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
def save_variable(v,filename):
    f=open(filename,'wb')
    pickle.dump(v,f)
    f.close()
    return filename
def load_variavle(filename):
   f=open(filename,'rb')
   r=pickle.load(f)
   f.close()
   return r

# %%
train = pd.read_csv('比赛训练集.csv', encoding='gbk')
test = pd.read_csv('比赛测试集.csv', encoding='gbk')

# %%
train_label = train['患有糖尿病标识']

# %% [markdown]
# ### 将文本转化为数值型

# %%
def FHOD(a):
    if a=='无记录':
        return 0
    elif a=='叔叔或者姑姑有一方患有糖尿病' or a=='叔叔或姑姑有一方患有糖尿病':
        return 1
    else:
        return 2
    
train['糖尿病家族史']=train['糖尿病家族史'].apply(FHOD)
test['糖尿病家族史']=test['糖尿病家族史'].apply(FHOD)

# %% [markdown]
# ## 查看标签数据分布

# %%
train_label.value_counts()
# Out:
# 患有糖尿病标识
# 0    3134
# 1    1936
# Name: count, dtype: int64

# %% [markdown]
# ##比赛数据分析

# %% [markdown]
# ### .corr()计算字段之间的相关性
# 通过柱状图和热力图可以看出 体重指数	和 肱三头肌皮褶厚度与标签有较高的相关性

# %% [markdown]
# #### 绘制柱状图

# %%
train.drop(columns='编号').corr()['患有糖尿病标识'].sort_values(ascending = False).plot(kind='bar')
plt.savefig('标签数据分布(备用)/患有糖尿病标识.jpg')

# %% [markdown]
# ### 绘制热力图

# %%
plt.figure(figsize=(20,20))
sns.heatmap(train.drop(columns='编号').corr(), annot=True, vmax=1, vmin=-1,cmap='Blues',annot_kws={'size':15})
plt.savefig('标签数据分布(备用)/热力图.jpg')
plt.show()

# %%
train
# Out:
#         编号  性别  出生年份  体重指数  糖尿病家族史    舒张压  口服耐糖量测试  胰岛素释放实验  肱三头肌皮褶厚度  患有糖尿病标识
# 0        1   0  1996  30.1       0  106.0    3.818     7.89       0.0        0
# 1        2   0  1988  27.5       0   84.0   -1.000     0.00      14.7        0
# 2        3   1  1988  36.5       0   85.0    7.131     0.00      40.1        1
# 3        4   1  1992  29.5       0   91.0    7.041     0.00       0.0        0
# 4        5   0  1998  42.0       1    NaN    7.134     0.00       0.0        1
# ...    ...  ..   ...   ...     ...    ...      ...      ...       ...      ...
# 5065  5066   1  1992  36.4       2   95.0    3.102     0.00       0.0        0
# 5066  5067   1  1991  37.1       1   94.0    6.207     6.77       0.0        0
# 5067  5068   0  1975  25.4       0   90.0    7.343     0.00       0.0        0
# 5068  5069   0  1972  28.5       2  101.0    6.268     8.99       0.0        0
# 5069  5070   0  1976  49.9       0   88.0    3.732    29.71       0.0        1
#
# [5070 rows x 10 columns]

# %% [markdown]
# ### 查看类别特征的标签占比
# 两种类别特征在占比上无明显区别

# %%
type_columns = ['性别','糖尿病家族史']

# %%
for var in type_columns:
    showing_prop=train.groupby(var)['患有糖尿病标识'].value_counts(normalize=True).unstack('患有糖尿病标识').sort_values(by=train['患有糖尿病标识'].unique()[0],ascending=False)
    showing_prop.plot(kind='bar', stacked=True,alpha=0.7)
    plt.savefig('标签数据分布(备用)/患有糖尿病标识{}.jpg'.format(var))
    plt.show()

# %% [markdown]
# ### 不同性别数量
# 女性患者数量多余男性

# %%
sns.countplot(x='患有糖尿病标识', hue='性别', data=train)
plt.savefig('标签数据分布(备用)/不同性别的患病数量.jpg')

# %% [markdown]
# ### 查看连续特征
# 胰岛素释放实验 和 肱三头肌皮褶厚度的有效值较少大部分为0
# 口服耐糖量测试的-1数量较多考虑不进行处理

# %%
num_columns = ['出生年份', '体重指数', '舒张压', '口服耐糖量测试', '胰岛素释放实验', '肱三头肌皮褶厚度']

# %%
for i in num_columns:
    sns.distplot(train[i])
    plt.savefig('标签数据分布(备用)/{}.jpg'.format(i))
    plt.show()

# %% [markdown]
# ### 缺失值计算

# %%
train.isnull().mean(0)
# Out:
# 编号          0.0
# 性别          0.0
# 出生年份        0.0
# 体重指数        0.0
# 糖尿病家族史      0.0
# 舒张压         0.0
# 口服耐糖量测试     0.0
# 胰岛素释放实验     0.0
# 肱三头肌皮褶厚度    0.0
# 患有糖尿病标识     0.0
# dtype: float64

# %%
test.isnull().mean(0)
# Out:
# 编号          0.0
# 性别          0.0
# 出生年份        0.0
# 体重指数        0.0
# 糖尿病家族史      0.0
# 舒张压         0.0
# 口服耐糖量测试     0.0
# 胰岛素释放实验     0.0
# 肱三头肌皮褶厚度    0.0
# dtype: float64

# %%
train['舒张压'].mean()
# Out:
# 89.40295857988166

# %%
test['舒张压'].mean()
# Out:
# 89.607

# %% [markdown]
# ### 均值填充

# %%
train['舒张压']=train['舒张压'].fillna(89)
test['舒张压']=test['舒张压'].fillna(89)

# %% [markdown]
# # 逻辑回归尝试

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(train.drop(columns=['编号','患有糖尿病标识']))
X = scaler.transform(train.drop(columns=['编号','患有糖尿病标识']))

# %%
y = train['患有糖尿病标识']

# %%
lg_model = LogisticRegression()

# %%
lg_model.fit(X,y)
# Out:
# LogisticRegression()

# %%
x_test = scaler.transform(test.drop(columns='编号'))

# %%
pre = lg_model.predict(x_test)

# %%
pre_y=pd.DataFrame(pre)
pre_y['label']=pre_y[0].apply(lambda x:1 if x>0.5 else 0)
result=pd.read_csv('提交示例.csv')
result['label']=pre_y['label']
result.to_csv('暂存数据(备用)/逻辑回归.csv',index=False)

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/reh7w9jlgm.jpg?imageView2/0/w/960/h/960)

# %% [markdown]
# # 特征工程
# 1.分箱
# 2.年份转换

# %%
"""
人体的成人体重指数正常值是在18.5-24之间
低于18.5是体重指数过轻
在24-27之间是体重超重
27以上考虑是肥胖
高于32了就是非常的肥胖。
"""
def BMI(a):
    if a<18.5:
        return 0
    elif 18.5<=a<=24:
        return 1
    elif 24<a<=27:
        return 2
    elif 27<a<=32:
        return 3
    else:
        return 4
    
train['BMI']=train['体重指数'].apply(BMI)
test['BMI']=test['体重指数'].apply(BMI)

train['出生年份']=2022-train['出生年份']  #换成年龄
test['出生年份']=2022-test['出生年份'] 

def DBP(a):
    if a<60:
        return 0
    elif 60<=a<=90:
        return 1
    elif a>90:
        return 2
    else:
        return a
train['DBP']=train['舒张压'].apply(DBP)
test['DBP']=test['舒张压'].apply(DBP)

# %% [markdown]
# # 构造评价指标F1

# %%
from sklearn.metrics import f1_score, roc_auc_score
def lgb_f1_score(y_hat, data):
    y_true = data.get_label()
    y_hat = np.round(y_hat)
    return 'f1', f1_score(y_true, y_hat) ,True

# %% [markdown]
# # lgb模型 + 交叉验证

# %%
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, KFold

# %%
def cv_model(clf, train_x, train_y, test_x, clf_name):
    folds = 5
    seed = 2022
    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)

    train = np.zeros(train_x.shape[0])
    test = np.zeros(test_x.shape[0])

    cv_scores = []
    f1_scores = []

    for i, (train_index, valid_index) in enumerate(kf.split(train_x, train_y)):
        print('************************************ {} ************************************'.format(str(i+1)))
        trn_x, trn_y, val_x, val_y = train_x.iloc[train_index], train_y[train_index], train_x.iloc[valid_index], train_y[valid_index]

        if clf_name == "lgb":
            train_matrix = clf.Dataset(trn_x, label=trn_y)
            valid_matrix = clf.Dataset(val_x, label=val_y)

            params = {
                'boosting_type': 'gbdt',
                'objective': 'binary',
                'metric': 'auc',
                'min_child_weight': 5,
                'num_leaves': 2 ** 5,
                'lambda_l2': 10,
                'feature_fraction': 0.7,
                'bagging_fraction': 0.7,
                'bagging_freq': 10,
                'learning_rate': 0.2,
                'seed': 2022,
                'verbosity': -1,
                'device' : 'gpu',
                'gpu_platform_id' : 1,
                'gpu_device_id' : 1,
                'n_jobs':-1,
            }

            # model = clf.train(params, train_matrix, 50000, valid_sets=[train_matrix, valid_matrix], 
            #                   feval=lgb_f1_score,
            #                   categorical_feature=[], verbose_eval=3000, early_stopping_rounds=200)
            # model = clf.train(params, train_matrix, 50000, valid_sets=[train_matrix, valid_matrix], 
            #                   feval=lgb_f1_score,
            #                   categorical_feature=[])
             # 50000的运算量巨大
            model = clf.train(params, train_matrix, 500, valid_sets=[train_matrix, valid_matrix], 
                              feval=lgb_f1_score,
                              categorical_feature=[])
            val_pred = model.predict(val_x, num_iteration=model.best_iteration)
            test_pred = model.predict(test_x, num_iteration=model.best_iteration)
            
#             print(list(sorted(zip(features, model.feature_importance("gain")), key=lambda x: x[1], reverse=True))[:20])
                
        if clf_name == "xgb":
            train_matrix = clf.DMatrix(trn_x , label=trn_y)
            valid_matrix = clf.DMatrix(val_x , label=val_y)
            test_matrix = clf.DMatrix(test_x)
            
            params = {'booster': 'gbtree',
                      'objective': 'binary:logistic',
                      'eval_metric': 'auc',
                      'gamma': 1,
                      'min_child_weight': 1.5,
                      'max_depth': 5,
                      'lambda': 10,
                      'subsample': 0.7,
                      'colsample_bytree': 0.7,
                      'colsample_bylevel': 0.7,
                      'eta': 0.2,
                      'seed': 2020,
                      'nthread': 36,
                      "silent": True,
                      }
            
            watchlist = [(train_matrix, 'train'),(valid_matrix, 'eval')]
            
            # model = clf.train(params, train_matrix, num_boost_round=50000, evals=watchlist, verbose_eval=3000, early_stopping_rounds=200)
            model = clf.train(params, train_matrix, num_boost_round=50000, evals=watchlist)
            # val_pred  = model.predict(valid_matrix, ntree_limit=model.best_ntree_limit)
            # test_pred = model.predict(test_matrix , ntree_limit=model.best_ntree_limit)
            print(model)
            val_pred  = model.predict(valid_matrix, ntree_limit=model.best_ntree_limit)
            test_pred = model.predict(test_matrix , ntree_limit=model.best_ntree_limit)
                 
        if clf_name == "cat":
            params = {'learning_rate': 0.2, 'depth': 5, 'l2_leaf_reg': 10, 'bootstrap_type': 'Bernoulli',
                      'od_type': 'Iter', 'od_wait': 50, 'random_seed': 11, 'allow_writing_files': False}
            
            model = clf(iterations=20000, **params)
            model.fit(trn_x, trn_y, eval_set=(val_x, val_y),
                      cat_features=[], use_best_model=True, verbose=3000)
            
            val_pred  = model.predict(val_x)
            test_pred = model.predict(test_x)
            
        train[valid_index] = val_pred
        
        test += test_pred / kf.n_splits
        cv_scores.append(roc_auc_score(val_y, val_pred))
        f1_scores.append(f1_score(val_y, [1 if i > 0.5 else 0 for i in val_pred]))
        
        print(cv_scores)
        print(f1_scores)
       
    print("%s_scotrainre_list:" % clf_name, cv_scores)
    print("%s_score_mean:" % clf_name, np.mean(cv_scores))
    print("%s_score_std:" % clf_name, np.std(cv_scores))
    
    print("%s f1_scotrainre_list:" % clf_name, f1_scores)
    print("%s f1_score_mean:" % clf_name, np.mean(f1_scores))
    print("%s f1_score_std:" % clf_name, np.std(f1_scores))
    return train, test

def lgb_model(x_train, y_train, x_test):
    lgb_train, lgb_test = cv_model(lgb, x_train, y_train, x_test, "lgb")
    return lgb_train, lgb_test

# %%
lgb_train, lgb_test = lgb_model(train.drop(['编号', '患有糖尿病标识'],axis=1), train_label, test.drop(['编号'],axis=1))
# Out:
# ************************************ 1 ************************************
# [0.9880267352185089]
# [0.9483204134366926]
# ************************************ 2 ************************************
# [0.9880267352185089, 0.9903056004752318]
# [0.9483204134366926, 0.9390402075226978]
# ************************************ 3 ************************************
# [0.9880267352185089, 0.9903056004752318, 0.9855470247147115]
# [0.9483204134366926, 0.9390402075226978, 0.9282920469361147]
# ************************************ 4 ************************************
# [0.9880267352185089, 0.9903056004752318, 0.9855470247147115, 0.9849542416452443]
# [0.9483204134366926, 0.9390402075226978, 0.9282920469361147, 0.9317889317889319]
# ************************************ 5 ************************************
# [0.9880267352185089, 0.9903056004752318, 0.9855470247147115, 0.9849542416452443, 0.9931988520223816]
# [0.9483204134366926, 0.9390402075226978, 0.9282920469361147, 0.9317889317889319, 0.9517601043024773]
# lgb_scotrainre_list: [0.9880267352185089, 0.9903056004752318, 0.9855470247147115, 0.9849542416452443, 0.9931988520223816]
# lgb_score_mean: 0.9884064908152157
# lgb_score_std: 0.003059808113769429
# lgb f1_scotrainre_list: [0.9483204134366926, 0.9390402075226978, 0.9282920469361147, 0.9317889317889319, 0.9517601043024773]
# lgb f1_score_mean: 0.9398403407973829
# lgb f1_score_std: 0.009086483207161931

# %%
# lgb_train
# lgb_test
# 由于优化模型时间过长，所以保存过程变量，或机器学习的模型
# filename = save_variable(cv_scores,'process_variable(reserve)/cv_scores')
# filename = save_variable(np.mean(cv_scores),'process_variable(reserve)/mean_cv_scores')
# filename = save_variable(np.std(cv_scores),'process_variable(reserve)/std_cv_scores')
# filename = save_variable(f1_scores,'process_variable(reserve)/f1_scores')
# filename = save_variable(np.mean(f1_scores),'process_variable(reserve)/mean_f1_scores')
# filename = save_variable(np.std(f1_scores),'process_variable(reserve)/std_f1_scores')
filename = save_variable(lgb_train,'process_variable(reserve)/lgb_train')
filename = save_variable(lgb_test,'process_variable(reserve)/lgb_test')

# %%
# 读取过程变量，不再运行机器学习算法
# cv_scores = load_variavle('process_variable(reserve)/cv_scores')
# mean_cv_scores = load_variavle('mean_cv_scores')
# mean_cv_scores = load_variavle('mean_cv_scores')
# f1_scores = load_variavle('process_variable(reserve)/f1_scores')
# mean_f1_scores = load_variavle('mean_f1_scores')
# std_f1_scores = load_variavle('std_f1_scores')
lgb_train = load_variavle('process_variable(reserve)/lgb_train')
lgb_test = load_variavle('process_variable(reserve)/lgb_test')

# %%
pre_y=pd.DataFrame(lgb_test)
pre_y['label']=pre_y[0].apply(lambda x:1 if x>0.5 else 0)
result=pd.read_csv('提交示例.csv')
result['label']=pre_y['label']
result.to_csv('暂存数据(备用)/baseline2.csv',index=False)

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/reh7x07jgw.jpg?imageView2/0/w/960/h/960)

# %% [markdown]
# # 构造新特征
# 肱三头肌皮褶厚度女性正常在0.9*16.5 ，16.5 *1.2 男性正常在0.9*12.5， 12.5 *1.2
# 根据不同性别的肱三头肌皮褶厚度分箱

# %%
def TSF(sex, a):
    if a == 0:
        return -1
    else:
        if sex == 0:
            if a >= 16.5*1.2:
                return 0
            elif 0.9*16.5 < a < 16.5 *1.2:
                return 1
            elif 0.8*16.5 < a <=16.5*0.9:
                return 2
            elif 0.6*16.5 < a <= 0.8*16.5:
                return 3
            else:
                return 4
        if sex == 1:
            if a >= 12.5*1.2:
                return 0
            elif 0.9*12.5 < a < 12.5 *1.2:
                return 1
            elif 0.8*12.5 < a <=12.5*0.9:
                return 2
            elif 0.6*12.5 < a <= 0.8*12.5:
                return 3
            else:
                return 4

train['TSF']=train.apply(lambda x : TSF(x['性别'],x['肱三头肌皮褶厚度']), axis=1)
test['TSF']=test.apply(lambda x : TSF(x['性别'],x['肱三头肌皮褶厚度']), axis=1)

# %%
lgb_train, lgb_test = lgb_model(train.drop(['编号', '患有糖尿病标识'],axis=1), train_label, test.drop(['编号'],axis=1))
# Out:
# ************************************ 1 ************************************
# [0.9880267352185089]
# [0.9483204134366926]
# ************************************ 2 ************************************
# [0.9880267352185089, 0.9903056004752318]
# [0.9483204134366926, 0.9404145077720207]
# ************************************ 3 ************************************
# [0.9880267352185089, 0.9903056004752318, 0.9855470247147115]
# [0.9483204134366926, 0.9404145077720207, 0.9282920469361147]
# ************************************ 4 ************************************
# [0.9880267352185089, 0.9903056004752318, 0.9855470247147115, 0.9849542416452443]
# [0.9483204134366926, 0.9404145077720207, 0.9282920469361147, 0.9317889317889319]
# ************************************ 5 ************************************
# [0.9880267352185089, 0.9903056004752318, 0.9855470247147115, 0.9849542416452443, 0.9933351227468874]
# [0.9483204134366926, 0.9404145077720207, 0.9282920469361147, 0.9317889317889319, 0.9505208333333333]
# lgb_scotrainre_list: [0.9880267352185089, 0.9903056004752318, 0.9855470247147115, 0.9849542416452443, 0.9933351227468874]
# lgb_score_mean: 0.9884337449601169
# lgb_score_std: 0.003102679529094824
# lgb f1_scotrainre_list: [0.9483204134366926, 0.9404145077720207, 0.9282920469361147, 0.9317889317889319, 0.9505208333333333]
# lgb f1_score_mean: 0.9398673466534186
# lgb f1_score_std: 0.00876925141662042

# %%
filename = save_variable(lgb_train,'process_variable(reserve)/lgb_train2')
filename = save_variable(lgb_test,'process_variable(reserve)/lgb_test2')

# %%
lgb_train = load_variavle('process_variable(reserve)/lgb_train2')
lgb_test = load_variavle('process_variable(reserve)/lgb_test2')

# %%
pre_y=pd.DataFrame(lgb_test)
pre_y['label']=pre_y[0].apply(lambda x:1 if x>0.5 else 0)
result=pd.read_csv('提交示例.csv')
result['label']=pre_y['label']
result.to_csv('暂存数据(备用)/TSF.csv',index=False)

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/reh7xhsqt9.jpg?imageView2/0/w/960/h/960)

# %% [markdown]
# # 自动特征衍生构造新的特征

# %%
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures

# %%
data1=pd.read_csv('比赛训练集.csv',encoding='gbk')
data2=pd.read_csv('比赛测试集.csv',encoding='gbk')
#label标记为-1
data2['患有糖尿病标识']=-1
#训练集和测试机合并
data=pd.concat([data1,data2],axis=0,ignore_index=True)

    
data['BMI']=data['体重指数'].apply(BMI)
data['出生年份']=2022-data['出生年份']  #换成年龄
#糖尿病家族史

def FHOD(a):
    if a=='无记录':
        return 0
    elif a=='叔叔或者姑姑有一方患有糖尿病' or a=='叔叔或姑姑有一方患有糖尿病':
        return 1
    else:
        return 2
    
data['糖尿病家族史']=data['糖尿病家族史'].apply(FHOD)
data['舒张压']=data['舒张压'].fillna(-1)

def DBP(a):
    if a<60:
        return 0
    elif 60<=a<=90:
        return 1
    elif a>90:
        return 2
    else:
        return a
data['DBP']=data['舒张压'].apply(DBP)

# %% [markdown]
# ### 类别特征自动衍生

# %%
def Binary_Cross_Combination(colNames,features, OneHot=True):
    colNames_new_l = []
    features_new_l = []
    
    features = features[colNames]
    
    for col_index, col_name in enumerate(colNames):
        for col_sub_index in range(col_index+1, len(colNames)):
            
            newNames = col_name + '&' + colNames[col_sub_index]
            colNames_new_l.append(newNames)
            
            new_df = pd.Series(features[col_name].astype('str')
                              + '&'
                              + features[colNames[col_sub_index]].astype('str'),
                              name=col_name)
            features_new_l.append(new_df)
    
    features_new = pd.concat(features_new_l,axis=1)
    features_new.columns = colNames_new_l
#     colNames_new = colNames_new_l
    
    
    if OneHot == True:
        enc = preprocessing.OneHotEncoder()
        enc.fit_transform(features_new)
        # features_new = pd.DataFrame(enc.fit_transform(features_new).toarray(), columns=enc.get_feature_names())
        # colNames_new = enc.get_feature_names()
        # AttributeError: 'OneHotEncoder' object has no attribute 'get_feature_names',使用get_feature_names_out()
        features_new = pd.DataFrame(enc.fit_transform(features_new).toarray(), columns=enc.get_feature_names_out())
        colNames_new = enc.get_feature_names_out()
    return features_new, colNames_new

# %% [markdown]
# ### 连续特征自动衍生

# %%
def Binary_PolynomialFeatures(colNames, degree, features):
    colNames_new_l = []
    features_new_l = []
    
    features= features[colNames]
    
    for col_index, col_name in enumerate(colNames):
        for col_sub_index in range(col_index+1, len(colNames)):
            col_temp = [col_name] + [colNames[col_sub_index]]
            array_new_temp = PolynomialFeatures(degree=degree, include_bias=False).fit_transform(features[col_temp])
            features_new_l.append(pd.DataFrame(array_new_temp[:,2:]))
            
            for deg in range(2,degree+1):
                for i in range(deg+1):
                    col_name_temp = col_temp[0]+ '**' + str(deg-i) + '*' + col_temp[1] + '**' + str(i)
                    colNames_new_l.append(col_name_temp)
    
    features_new = pd.concat(features_new_l,axis=1)
    features_new.columns= colNames_new_l
    colNames_new = colNames_new_l
    
    return features_new, colNames_new

# %%
colNames = ['性别','BMI','DBP', '糖尿病家族史']
features_new, colNames_new = Binary_Cross_Combination(colNames, data)
numeric_cols = ['体重指数','舒张压','口服耐糖量测试','胰岛素释放实验','肱三头肌皮褶厚度']
features_new2, colNames_new2 = Binary_PolynomialFeatures(colNames=numeric_cols,degree=3,features=data)

# %%
data_new = pd.concat([data, features_new, features_new2],axis=1)

# %% [markdown]
# # 筛选自动衍生的特征

# %% [markdown]
# ### 卡方检验

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
var_sel = VarianceThreshold()
var_sel.fit(data_new)
# Out:
# VarianceThreshold()

# %%
data_new_cols = data_new.columns[var_sel.variances_ >0.0099]
data_new_cols = [i for i in data_new_cols if i not in ['编号','患有糖尿病标识']]

# %%
train_new=data_new[data_new['患有糖尿病标识'] !=-1]
test_new=data_new[data_new['患有糖尿病标识'] ==-1]
train_label=train_new['患有糖尿病标识']
train_new=train_new.drop(['编号','患有糖尿病标识'],axis=1)
test_new=test_new.drop(['编号','患有糖尿病标识'],axis=1)

# %% [markdown]
# ### 互信息过滤

# %%
from sklearn.feature_selection import mutual_info_classif as MIC

# %%
mic = MIC(train_new[list(colNames_new)+list(colNames_new2)], train_label)

# %%
MIC_threshold = mic.mean()*0.1
MIC_train_new_cols = []
for mic_value, column in zip(mic, list(colNames_new)+list(colNames_new2)):
    if mic_value > MIC_threshold:
        MIC_train_new_cols.append(column)

# %%
final_feature = data.columns.tolist() + MIC_train_new_cols
final_feature = [i for i in final_feature if i not in ['编号','患有糖尿病标识']]

# %%
lgb_train, lgb_test = lgb_model(train_new[final_feature], train_label, test_new[final_feature])
# Out:
# ************************************ 1 ************************************
# [0.9890179948586119]
# [0.950261780104712]
# ************************************ 2 ************************************
# [0.9890179948586119, 0.9906397478631068]
# [0.950261780104712, 0.9367741935483871]
# ************************************ 3 ************************************
# [0.9890179948586119, 0.9906397478631068, 0.9867668937436379]
# [0.950261780104712, 0.9367741935483871, 0.9250645994832042]
# ************************************ 4 ************************************
# [0.9890179948586119, 0.9906397478631068, 0.9867668937436379, 0.9843331619537274]
# [0.950261780104712, 0.9367741935483871, 0.9250645994832042, 0.9345314505776636]
# ************************************ 5 ************************************
# [0.9890179948586119, 0.9906397478631068, 0.9867668937436379, 0.9843331619537274, 0.9911919558978383]
# [0.950261780104712, 0.9367741935483871, 0.9250645994832042, 0.9345314505776636, 0.9479166666666666]
# lgb_scotrainre_list: [0.9890179948586119, 0.9906397478631068, 0.9867668937436379, 0.9843331619537274, 0.9911919558978383]
# lgb_score_mean: 0.9883899508633844
# lgb_score_std: 0.0025455493978503553
# lgb f1_scotrainre_list: [0.950261780104712, 0.9367741935483871, 0.9250645994832042, 0.9345314505776636, 0.9479166666666666]
# lgb f1_score_mean: 0.9389097380761268
# lgb f1_score_std: 0.009224006020815911

# %%
filename = save_variable(lgb_train,'process_variable(reserve)/lgb_train3')
filename = save_variable(lgb_test,'process_variable(reserve)/lgb_test3')

# %%
lgb_train = load_variavle('process_variable(reserve)/lgb_train3')
lgb_test = load_variavle('process_variable(reserve)/lgb_test3')

# %%
pre_y=pd.DataFrame(lgb_test)
pre_y['label']=pre_y[0].apply(lambda x:1 if x>0.5 else 0)
result=pd.read_csv('提交示例.csv')
result['label']=pre_y['label']
result.to_csv('暂存数据(备用)/特征衍生.csv',index=False)

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/reh7y0yvvi.jpg?imageView2/0/w/960/h/960)

# %% [markdown]
# # stacking
# xgb和lgb做stacking，线性回归做分类器

# %%
import xgboost as xgb
from sklearn.linear_model import LinearRegression

# %%
def cv_model(clf, train_x, train_y, test_x, clf_name):
    folds = 5
    seed = 2022
    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)

    train = np.zeros(train_x.shape[0])
    test = np.zeros(test_x.shape[0])

    cv_scores = []
    f1_scores = []

    for i, (train_index, valid_index) in enumerate(kf.split(train_x, train_y)):
        print('************************************ {} ************************************'.format(str(i+1)))
        trn_x, trn_y, val_x, val_y = train_x.iloc[train_index], train_y[train_index], train_x.iloc[valid_index], train_y[valid_index]
                
        if clf_name == "xgb":
            train_matrix = clf.DMatrix(trn_x , label=trn_y)
            valid_matrix = clf.DMatrix(val_x , label=val_y)
            test_matrix = clf.DMatrix(test_x)
            
            params = {'booster': 'gbtree',
                      'objective': 'binary:logistic',
                      'eval_metric': 'auc',
                      'gamma': 1,
                      'min_child_weight': 1.5,
                      'max_depth': 5,
                      'lambda': 10,
                      'subsample': 0.7,
                      'colsample_bytree': 0.7,
                      'colsample_bylevel': 0.7,
                      'eta': 0.2,
                      'seed': 2020,
                      'nthread': 36,
                      "silent": True,
                      }
            
            watchlist = [(train_matrix, 'train'),(valid_matrix, 'eval')]
            
            # model = clf.train(params, train_matrix, num_boost_round=50000, evals=watchlist, verbose_eval=3000, early_stopping_rounds=200)
            # 50000数据量太大，选择500
            # model = clf.train(params, train_matrix, num_boost_round=50000, evals=watchlist)
            model = clf.train(params, train_matrix, num_boost_round=500, evals=watchlist)
            # val_pred  = model.predict(valid_matrix, ntree_limit=model.best_ntree_limit)
            # test_pred = model.predict(test_matrix , ntree_limit=model.best_ntree_limit)
            val_pred  = model.predict(valid_matrix)
            test_pred = model.predict(test_matrix)
                 
            
        train[valid_index] = val_pred
        
        test += test_pred / kf.n_splits
        cv_scores.append(roc_auc_score(val_y, val_pred))
        f1_scores.append(f1_score(val_y, [1 if i > 0.5 else 0 for i in val_pred]))
        
        print(cv_scores)
        print(f1_scores)
       
    print("%s_scotrainre_list:" % clf_name, cv_scores)
    print("%s_score_mean:" % clf_name, np.mean(cv_scores))
    print("%s_score_std:" % clf_name, np.std(cv_scores))
    
    print("%s f1_scotrainre_list:" % clf_name, f1_scores)
    print("%s f1_score_mean:" % clf_name, np.mean(f1_scores))
    print("%s f1_score_std:" % clf_name, np.std(f1_scores))
    return train, test

# %%
def xgb_model(x_train, y_train, x_test):
    xgb_train, xgb_test = cv_model(xgb, x_train, y_train, x_test, "xgb")
    return xgb_train, xgb_test

# %%
xgb_train, xgb_test = xgb_model(train_new[final_feature], train_label, test_new[final_feature])
# Out:
# ************************************ 1 ************************************
# [0]	train-auc:0.96914	eval-auc:0.96405
# [1]	train-auc:0.97038	eval-auc:0.96540
# [2]	train-auc:0.97362	eval-auc:0.97123
# [3]	train-auc:0.97401	eval-auc:0.97118
# [4]	train-auc:0.97393	eval-auc:0.97123
# [5]	train-auc:0.97513	eval-auc:0.97148
# [6]	train-auc:0.97519	eval-auc:0.97156
# [7]	train-auc:0.97564	eval-auc:0.97162
# [8]	train-auc:0.97550	eval-auc:0.97137
# [9]	train-auc:0.98695	eval-auc:0.98661
# [10]	train-auc:0.98668	eval-auc:0.98627
# [11]	train-auc:0.98690	eval-auc:0.98647
# [12]	train-auc:0.98886	eval-auc:0.98662
# [13]	train-auc:0.98908	eval-auc:0.98658
# [14]	train-auc:0.98993	eval-auc:0.98738
# [15]	train-auc:0.99002	eval-auc:0.98730
# [16]	train-auc:0.99019	eval-auc:0.98727
# [17]	train-auc:0.99069	eval-auc:0.98721
# [18]	train-auc:0.99122	eval-auc:0.98723
# [19]	train-auc:0.99139	eval-auc:0.98755
# [20]	train-auc:0.99185	eval-auc:0.98832
# [21]	train-auc:0.99192	eval-auc:0.98832
# [22]	train-auc:0.99256	eval-auc:0.98899
# [23]	train-auc:0.99278	eval-auc:0.98934
# [24]	train-auc:0.99313	eval-auc:0.98973
# [25]	train-auc:0.99331	eval-auc:0.98944
# [26]	train-auc:0.99342	eval-auc:0.98950
# [27]	train-auc:0.99368	eval-auc:0.98962
# [28]	train-auc:0.99370	eval-auc:0.99030
# [29]	train-auc:0.99379	eval-auc:0.99014
# [30]	train-auc:0.99414	eval-auc:0.98963
# [31]	train-auc:0.99414	eval-auc:0.99007
# [32]	train-auc:0.99426	eval-auc:0.99013
# [33]	train-auc:0.99435	eval-auc:0.98956
# [34]	train-auc:0.99450	eval-auc:0.98940
# [35]	train-auc:0.99455	eval-auc:0.98980
# [36]	train-auc:0.99471	eval-auc:0.98998
# [37]	train-auc:0.99481	eval-auc:0.98967
# [38]	train-auc:0.99499	eval-auc:0.99026
# [39]	train-auc:0.99505	eval-auc:0.99034
# [40]	train-auc:0.99519	eval-auc:0.99015
# [41]	train-auc:0.99537	eval-auc:0.99042
# [42]	train-auc:0.99554	eval-auc:0.99024
# [43]	train-auc:0.99567	eval-auc:0.99014
# [44]	train-auc:0.99569	eval-auc:0.98984
# [45]	train-auc:0.99585	eval-auc:0.98977
# [46]	train-auc:0.99594	eval-auc:0.98961
# [47]	train-auc:0.99601	eval-auc:0.98987
# [48]	train-auc:0.99608	eval-auc:0.98967
# [49]	train-auc:0.99617	eval-auc:0.98993
# [50]	train-auc:0.99617	eval-auc:0.98997
# [51]	train-auc:0.99627	eval-auc:0.99011
# [52]	train-auc:0.99630	eval-auc:0.98994
# [53]	train-auc:0.99633	eval-auc:0.98992
# [54]	train-auc:0.99641	eval-auc:0.99030
# [55]	train-auc:0.99650	eval-auc:0.99036
# [56]	train-auc:0.99655	eval-auc:0.99040
# [57]	train-auc:0.99667	eval-auc:0.99028
# [58]	train-auc:0.99673	eval-auc:0.99019
# [59]	train-auc:0.99673	eval-auc:0.99019
# [60]	train-auc:0.99675	eval-auc:0.99005
# [61]	train-auc:0.99682	eval-auc:0.99012
# [62]	train-auc:0.99686	eval-auc:0.98994
# [63]	train-auc:0.99683	eval-auc:0.98998
# [64]	train-auc:0.99688	eval-auc:0.99001
# [65]	train-auc:0.99689	eval-auc:0.99002
# [66]	train-auc:0.99694	eval-auc:0.98987
# [67]	train-auc:0.99698	eval-auc:0.98987
# [68]	train-auc:0.99699	eval-auc:0.98992
# [69]	train-auc:0.99703	eval-auc:0.98972
# [70]	train-auc:0.99708	eval-auc:0.98966
# [71]	train-auc:0.99711	eval-auc:0.98976
# [72]	train-auc:0.99716	eval-auc:0.98953
# [73]	train-auc:0.99718	eval-auc:0.98958
# [74]	train-auc:0.99723	eval-auc:0.98968
# [75]	train-auc:0.99726	eval-auc:0.98956
# [76]	train-auc:0.99730	eval-auc:0.98943
# [77]	train-auc:0.99733	eval-auc:0.98944
# [78]	train-auc:0.99740	eval-auc:0.98946
# [79]	train-auc:0.99741	eval-auc:0.98943
# [80]	train-auc:0.99743	eval-auc:0.98947
# [81]	train-auc:0.99744	eval-auc:0.98941
# [82]	train-auc:0.99743	eval-auc:0.98951
# [83]	train-auc:0.99743	eval-auc:0.98951
# [84]	train-auc:0.99746	eval-auc:0.98945
# [85]	train-auc:0.99750	eval-auc:0.98951
# [86]	train-auc:0.99748	eval-auc:0.98966
# [87]	train-auc:0.99750	eval-auc:0.98966
# [88]	train-auc:0.99749	eval-auc:0.98965
# [89]	train-auc:0.99750	eval-auc:0.98963
# [90]	train-auc:0.99754	eval-auc:0.98957
# [91]	train-auc:0.99754	eval-auc:0.98957
# [92]	train-auc:0.99757	eval-auc:0.98962
# [93]	train-auc:0.99759	eval-auc:0.98958
# [94]	train-auc:0.99763	eval-auc:0.98950
# [95]	train-auc:0.99764	eval-auc:0.98947
# [96]	train-auc:0.99771	eval-auc:0.98944
# [97]	train-auc:0.99772	eval-auc:0.98947
# [98]	train-auc:0.99774	eval-auc:0.98953
# [99]	train-auc:0.99779	eval-auc:0.98948
# [100]	train-auc:0.99780	eval-auc:0.98947
# [101]	train-auc:0.99784	eval-auc:0.98940
# [102]	train-auc:0.99787	eval-auc:0.98925
# [103]	train-auc:0.99787	eval-auc:0.98925
# [104]	train-auc:0.99788	eval-auc:0.98920
# [105]	train-auc:0.99788	eval-auc:0.98917
# [106]	train-auc:0.99788	eval-auc:0.98917
# [107]	train-auc:0.99789	eval-auc:0.98923
# [108]	train-auc:0.99789	eval-auc:0.98929
# [109]	train-auc:0.99789	eval-auc:0.98929
# [110]	train-auc:0.99796	eval-auc:0.98939
# [111]	train-auc:0.99798	eval-auc:0.98948
# [112]	train-auc:0.99798	eval-auc:0.98948
# [113]	train-auc:0.99799	eval-auc:0.98952
# [114]	train-auc:0.99802	eval-auc:0.98952
# [115]	train-auc:0.99802	eval-auc:0.98952
# [116]	train-auc:0.99802	eval-auc:0.98952
# [117]	train-auc:0.99803	eval-auc:0.98950
# [118]	train-auc:0.99803	eval-auc:0.98950
# [119]	train-auc:0.99802	eval-auc:0.98945
# [120]	train-auc:0.99802	eval-auc:0.98945
# [121]	train-auc:0.99802	eval-auc:0.98945
# [122]	train-auc:0.99804	eval-auc:0.98941
# [123]	train-auc:0.99804	eval-auc:0.98941
# [124]	train-auc:0.99807	eval-auc:0.98957
# [125]	train-auc:0.99809	eval-auc:0.98973
# [126]	train-auc:0.99810	eval-auc:0.98968
# [127]	train-auc:0.99810	eval-auc:0.98968
# [128]	train-auc:0.99810	eval-auc:0.98968
# [129]	train-auc:0.99813	eval-auc:0.98984
# [130]	train-auc:0.99814	eval-auc:0.98977
# [131]	train-auc:0.99815	eval-auc:0.98976
# [132]	train-auc:0.99815	eval-auc:0.98966
# [133]	train-auc:0.99815	eval-auc:0.98965
# [134]	train-auc:0.99815	eval-auc:0.98963
# [135]	train-auc:0.99815	eval-auc:0.98963
# [136]	train-auc:0.99815	eval-auc:0.98963
# [137]	train-auc:0.99816	eval-auc:0.98967
# [138]	train-auc:0.99816	eval-auc:0.98967
# [139]	train-auc:0.99816	eval-auc:0.98967
# [140]	train-auc:0.99817	eval-auc:0.98965
# [141]	train-auc:0.99817	eval-auc:0.98951
# [142]	train-auc:0.99818	eval-auc:0.98950
# [143]	train-auc:0.99820	eval-auc:0.98949
# [144]	train-auc:0.99820	eval-auc:0.98949
# [145]	train-auc:0.99820	eval-auc:0.98954
# [146]	train-auc:0.99820	eval-auc:0.98954
# [147]	train-auc:0.99822	eval-auc:0.98947
# [148]	train-auc:0.99823	eval-auc:0.98944
# [149]	train-auc:0.99825	eval-auc:0.98937
# [150]	train-auc:0.99825	eval-auc:0.98937
# [151]	train-auc:0.99825	eval-auc:0.98937
# [152]	train-auc:0.99824	eval-auc:0.98929
# [153]	train-auc:0.99825	eval-auc:0.98933
# [154]	train-auc:0.99827	eval-auc:0.98928
# [155]	train-auc:0.99827	eval-auc:0.98928
# [156]	train-auc:0.99830	eval-auc:0.98931
# [157]	train-auc:0.99830	eval-auc:0.98931
# [158]	train-auc:0.99830	eval-auc:0.98938
# [159]	train-auc:0.99830	eval-auc:0.98938
# [160]	train-auc:0.99833	eval-auc:0.98943
# [161]	train-auc:0.99833	eval-auc:0.98939
# [162]	train-auc:0.99838	eval-auc:0.98946
# [163]	train-auc:0.99838	eval-auc:0.98938
# [164]	train-auc:0.99838	eval-auc:0.98938
# [165]	train-auc:0.99839	eval-auc:0.98938
# [166]	train-auc:0.99839	eval-auc:0.98941
# [167]	train-auc:0.99841	eval-auc:0.98933
# [168]	train-auc:0.99843	eval-auc:0.98936
# [169]	train-auc:0.99840	eval-auc:0.98955
# [170]	train-auc:0.99842	eval-auc:0.98954
# [171]	train-auc:0.99842	eval-auc:0.98954
# [172]	train-auc:0.99845	eval-auc:0.98967
# [173]	train-auc:0.99846	eval-auc:0.98953
# [174]	train-auc:0.99846	eval-auc:0.98950
# [175]	train-auc:0.99846	eval-auc:0.98954
# [176]	train-auc:0.99846	eval-auc:0.98954
# [177]	train-auc:0.99848	eval-auc:0.98962
# [178]	train-auc:0.99848	eval-auc:0.98962
# [179]	train-auc:0.99848	eval-auc:0.98965
# [180]	train-auc:0.99848	eval-auc:0.98965
# [181]	train-auc:0.99852	eval-auc:0.98953
# [182]	train-auc:0.99852	eval-auc:0.98953
# [183]	train-auc:0.99852	eval-auc:0.98953
# [184]	train-auc:0.99852	eval-auc:0.98953
# [185]	train-auc:0.99851	eval-auc:0.98952
# [186]	train-auc:0.99851	eval-auc:0.98952
# [187]	train-auc:0.99851	eval-auc:0.98952
# [188]	train-auc:0.99851	eval-auc:0.98952
# [189]	train-auc:0.99851	eval-auc:0.98952
# [190]	train-auc:0.99852	eval-auc:0.98961
# [191]	train-auc:0.99855	eval-auc:0.98960
# [192]	train-auc:0.99855	eval-auc:0.98960
# [193]	train-auc:0.99855	eval-auc:0.98960
# [194]	train-auc:0.99855	eval-auc:0.98960
# [195]	train-auc:0.99854	eval-auc:0.98959
# [196]	train-auc:0.99855	eval-auc:0.98962
# [197]	train-auc:0.99855	eval-auc:0.98970
# [198]	train-auc:0.99855	eval-auc:0.98970
# [199]	train-auc:0.99855	eval-auc:0.98970
# [200]	train-auc:0.99856	eval-auc:0.98975
# [201]	train-auc:0.99856	eval-auc:0.98975
# [202]	train-auc:0.99856	eval-auc:0.98972
# [203]	train-auc:0.99858	eval-auc:0.98968
# [204]	train-auc:0.99858	eval-auc:0.98975
# [205]	train-auc:0.99858	eval-auc:0.98976
# [206]	train-auc:0.99858	eval-auc:0.98976
# [207]	train-auc:0.99859	eval-auc:0.98975
# [208]	train-auc:0.99859	eval-auc:0.98975
# [209]	train-auc:0.99860	eval-auc:0.98985
# [210]	train-auc:0.99860	eval-auc:0.98978
# [211]	train-auc:0.99860	eval-auc:0.98978
# [212]	train-auc:0.99861	eval-auc:0.98977
# [213]	train-auc:0.99864	eval-auc:0.98984
# [214]	train-auc:0.99863	eval-auc:0.98974
# [215]	train-auc:0.99863	eval-auc:0.98974
# [216]	train-auc:0.99865	eval-auc:0.98980
# [217]	train-auc:0.99865	eval-auc:0.98984
# [218]	train-auc:0.99865	eval-auc:0.98984
# [219]	train-auc:0.99865	eval-auc:0.98984
# [220]	train-auc:0.99865	eval-auc:0.98984
# [221]	train-auc:0.99864	eval-auc:0.98983
# [222]	train-auc:0.99864	eval-auc:0.98983
# [223]	train-auc:0.99864	eval-auc:0.98983
# [224]	train-auc:0.99863	eval-auc:0.98982
# [225]	train-auc:0.99863	eval-auc:0.98966
# [226]	train-auc:0.99864	eval-auc:0.98969
# [227]	train-auc:0.99865	eval-auc:0.98967
# [228]	train-auc:0.99866	eval-auc:0.98962
# [229]	train-auc:0.99866	eval-auc:0.98962
# [230]	train-auc:0.99866	eval-auc:0.98968
# [231]	train-auc:0.99867	eval-auc:0.98971
# [232]	train-auc:0.99870	eval-auc:0.98971
# [233]	train-auc:0.99870	eval-auc:0.98972
# [234]	train-auc:0.99871	eval-auc:0.98976
# [235]	train-auc:0.99872	eval-auc:0.98978
# [236]	train-auc:0.99872	eval-auc:0.98983
# [237]	train-auc:0.99872	eval-auc:0.98978
# [238]	train-auc:0.99873	eval-auc:0.98985
# [239]	train-auc:0.99874	eval-auc:0.99002
# [240]	train-auc:0.99874	eval-auc:0.98996
# [241]	train-auc:0.99874	eval-auc:0.98996
# [242]	train-auc:0.99874	eval-auc:0.98988
# [243]	train-auc:0.99875	eval-auc:0.98994
# [244]	train-auc:0.99875	eval-auc:0.98994
# [245]	train-auc:0.99875	eval-auc:0.98990
# [246]	train-auc:0.99874	eval-auc:0.98989
# [247]	train-auc:0.99874	eval-auc:0.98989
# [248]	train-auc:0.99874	eval-auc:0.98985
# [249]	train-auc:0.99874	eval-auc:0.98985
# [250]	train-auc:0.99874	eval-auc:0.98985
# [251]	train-auc:0.99874	eval-auc:0.98980
# [252]	train-auc:0.99874	eval-auc:0.98980
# [253]	train-auc:0.99874	eval-auc:0.98980
# [254]	train-auc:0.99874	eval-auc:0.98980
# [255]	train-auc:0.99875	eval-auc:0.98979
# [256]	train-auc:0.99874	eval-auc:0.98975
# [257]	train-auc:0.99877	eval-auc:0.98980
# [258]	train-auc:0.99879	eval-auc:0.98980
# [259]	train-auc:0.99879	eval-auc:0.98987
# [260]	train-auc:0.99879	eval-auc:0.98987
# [261]	train-auc:0.99880	eval-auc:0.98979
# [262]	train-auc:0.99881	eval-auc:0.98974
# [263]	train-auc:0.99882	eval-auc:0.98968
# [264]	train-auc:0.99882	eval-auc:0.98970
# [265]	train-auc:0.99882	eval-auc:0.98973
# [266]	train-auc:0.99882	eval-auc:0.98973
# [267]	train-auc:0.99882	eval-auc:0.98973
# [268]	train-auc:0.99883	eval-auc:0.98973
# [269]	train-auc:0.99883	eval-auc:0.98973
# [270]	train-auc:0.99883	eval-auc:0.98973
# [271]	train-auc:0.99882	eval-auc:0.98972
# [272]	train-auc:0.99883	eval-auc:0.98965
# [273]	train-auc:0.99883	eval-auc:0.98965
# [274]	train-auc:0.99882	eval-auc:0.98968
# [275]	train-auc:0.99882	eval-auc:0.98965
# [276]	train-auc:0.99884	eval-auc:0.98968
# [277]	train-auc:0.99884	eval-auc:0.98979
# [278]	train-auc:0.99885	eval-auc:0.98976
# [279]	train-auc:0.99884	eval-auc:0.98972
# [280]	train-auc:0.99884	eval-auc:0.98972
# [281]	train-auc:0.99884	eval-auc:0.98972
# [282]	train-auc:0.99884	eval-auc:0.98972
# [283]	train-auc:0.99884	eval-auc:0.98975
# [284]	train-auc:0.99885	eval-auc:0.98971
# [285]	train-auc:0.99885	eval-auc:0.98971
# [286]	train-auc:0.99885	eval-auc:0.98977
# [287]	train-auc:0.99885	eval-auc:0.98973
# [288]	train-auc:0.99886	eval-auc:0.98978
# [289]	train-auc:0.99886	eval-auc:0.98983
# [290]	train-auc:0.99886	eval-auc:0.98983
# [291]	train-auc:0.99886	eval-auc:0.98983
# [292]	train-auc:0.99886	eval-auc:0.98983
# [293]	train-auc:0.99886	eval-auc:0.98983
# [294]	train-auc:0.99886	eval-auc:0.98983
# [295]	train-auc:0.99886	eval-auc:0.98983
# [296]	train-auc:0.99886	eval-auc:0.98973
# [297]	train-auc:0.99887	eval-auc:0.98972
# [298]	train-auc:0.99888	eval-auc:0.98967
# [299]	train-auc:0.99891	eval-auc:0.98970
# [300]	train-auc:0.99891	eval-auc:0.98970
# [301]	train-auc:0.99889	eval-auc:0.98968
# [302]	train-auc:0.99889	eval-auc:0.98968
# [303]	train-auc:0.99889	eval-auc:0.98968
# [304]	train-auc:0.99889	eval-auc:0.98968
# [305]	train-auc:0.99891	eval-auc:0.98966
# [306]	train-auc:0.99890	eval-auc:0.98966
# [307]	train-auc:0.99889	eval-auc:0.98967
# [308]	train-auc:0.99892	eval-auc:0.98977
# [309]	train-auc:0.99892	eval-auc:0.98977
# [310]	train-auc:0.99893	eval-auc:0.98977
# [311]	train-auc:0.99893	eval-auc:0.98977
# [312]	train-auc:0.99893	eval-auc:0.98977
# [313]	train-auc:0.99893	eval-auc:0.98977
# [314]	train-auc:0.99893	eval-auc:0.98977
# [315]	train-auc:0.99894	eval-auc:0.98975
# [316]	train-auc:0.99894	eval-auc:0.98975
# [317]	train-auc:0.99894	eval-auc:0.98975
# [318]	train-auc:0.99894	eval-auc:0.98975
# [319]	train-auc:0.99894	eval-auc:0.98979
# [320]	train-auc:0.99894	eval-auc:0.98979
# [321]	train-auc:0.99894	eval-auc:0.98980
# [322]	train-auc:0.99894	eval-auc:0.98980
# [323]	train-auc:0.99894	eval-auc:0.98982
# [324]	train-auc:0.99894	eval-auc:0.98982
# [325]	train-auc:0.99895	eval-auc:0.98972
# [326]	train-auc:0.99895	eval-auc:0.98972
# [327]	train-auc:0.99895	eval-auc:0.98973
# [328]	train-auc:0.99895	eval-auc:0.98973
# [329]	train-auc:0.99895	eval-auc:0.98973
# [330]	train-auc:0.99895	eval-auc:0.98973
# [331]	train-auc:0.99894	eval-auc:0.98973
# [332]	train-auc:0.99894	eval-auc:0.98962
# [333]	train-auc:0.99894	eval-auc:0.98962
# [334]	train-auc:0.99894	eval-auc:0.98958
# [335]	train-auc:0.99895	eval-auc:0.98970
# [336]	train-auc:0.99895	eval-auc:0.98970
# [337]	train-auc:0.99894	eval-auc:0.98968
# [338]	train-auc:0.99895	eval-auc:0.98973
# [339]	train-auc:0.99895	eval-auc:0.98972
# [340]	train-auc:0.99895	eval-auc:0.98967
# [341]	train-auc:0.99895	eval-auc:0.98967
# [342]	train-auc:0.99895	eval-auc:0.98966
# [343]	train-auc:0.99895	eval-auc:0.98966
# [344]	train-auc:0.99897	eval-auc:0.98954
# [345]	train-auc:0.99898	eval-auc:0.98947
# [346]	train-auc:0.99898	eval-auc:0.98947
# [347]	train-auc:0.99898	eval-auc:0.98947
# [348]	train-auc:0.99898	eval-auc:0.98951
# [349]	train-auc:0.99898	eval-auc:0.98951
# [350]	train-auc:0.99898	eval-auc:0.98951
# [351]	train-auc:0.99898	eval-auc:0.98950
# [352]	train-auc:0.99899	eval-auc:0.98948
# [353]	train-auc:0.99899	eval-auc:0.98948
# [354]	train-auc:0.99897	eval-auc:0.98958
# [355]	train-auc:0.99897	eval-auc:0.98958
# [356]	train-auc:0.99897	eval-auc:0.98958
# [357]	train-auc:0.99897	eval-auc:0.98958
# [358]	train-auc:0.99897	eval-auc:0.98958
# [359]	train-auc:0.99897	eval-auc:0.98958
# [360]	train-auc:0.99899	eval-auc:0.98960
# [361]	train-auc:0.99899	eval-auc:0.98960
# [362]	train-auc:0.99899	eval-auc:0.98962
# [363]	train-auc:0.99900	eval-auc:0.98963
# [364]	train-auc:0.99900	eval-auc:0.98963
# [365]	train-auc:0.99900	eval-auc:0.98972
# [366]	train-auc:0.99902	eval-auc:0.98976
# [367]	train-auc:0.99902	eval-auc:0.98976
# [368]	train-auc:0.99903	eval-auc:0.98982
# [369]	train-auc:0.99903	eval-auc:0.98982
# [370]	train-auc:0.99903	eval-auc:0.98982
# [371]	train-auc:0.99903	eval-auc:0.98982
# [372]	train-auc:0.99902	eval-auc:0.98982
# [373]	train-auc:0.99902	eval-auc:0.98982
# [374]	train-auc:0.99902	eval-auc:0.98976
# [375]	train-auc:0.99902	eval-auc:0.98976
# [376]	train-auc:0.99902	eval-auc:0.98970
# [377]	train-auc:0.99902	eval-auc:0.98970
# [378]	train-auc:0.99902	eval-auc:0.98970
# [379]	train-auc:0.99904	eval-auc:0.98973
# [380]	train-auc:0.99904	eval-auc:0.98973
# [381]	train-auc:0.99904	eval-auc:0.98973
# [382]	train-auc:0.99904	eval-auc:0.98973
# [383]	train-auc:0.99904	eval-auc:0.98973
# [384]	train-auc:0.99903	eval-auc:0.98967
# [385]	train-auc:0.99903	eval-auc:0.98967
# [386]	train-auc:0.99903	eval-auc:0.98967
# [387]	train-auc:0.99903	eval-auc:0.98967
# [388]	train-auc:0.99903	eval-auc:0.98967
# [389]	train-auc:0.99903	eval-auc:0.98967
# [390]	train-auc:0.99903	eval-auc:0.98967
# [391]	train-auc:0.99903	eval-auc:0.98967
# [392]	train-auc:0.99903	eval-auc:0.98967
# [393]	train-auc:0.99904	eval-auc:0.98975
# [394]	train-auc:0.99904	eval-auc:0.98975
# [395]	train-auc:0.99904	eval-auc:0.98975
# [396]	train-auc:0.99903	eval-auc:0.98973
# [397]	train-auc:0.99903	eval-auc:0.98973
# [398]	train-auc:0.99903	eval-auc:0.98973
# [399]	train-auc:0.99903	eval-auc:0.98973
# [400]	train-auc:0.99903	eval-auc:0.98973
# [401]	train-auc:0.99902	eval-auc:0.98969
# [402]	train-auc:0.99902	eval-auc:0.98969
# [403]	train-auc:0.99902	eval-auc:0.98969
# [404]	train-auc:0.99903	eval-auc:0.98973
# [405]	train-auc:0.99903	eval-auc:0.98973
# [406]	train-auc:0.99903	eval-auc:0.98973
# [407]	train-auc:0.99903	eval-auc:0.98973
# [408]	train-auc:0.99903	eval-auc:0.98966
# [409]	train-auc:0.99905	eval-auc:0.98982
# [410]	train-auc:0.99905	eval-auc:0.98984
# [411]	train-auc:0.99904	eval-auc:0.98983
# [412]	train-auc:0.99904	eval-auc:0.98983
# [413]	train-auc:0.99904	eval-auc:0.98983
# [414]	train-auc:0.99904	eval-auc:0.98981
# [415]	train-auc:0.99904	eval-auc:0.98981
# [416]	train-auc:0.99905	eval-auc:0.98984
# [417]	train-auc:0.99905	eval-auc:0.98984
# [418]	train-auc:0.99905	eval-auc:0.98984
# [419]	train-auc:0.99905	eval-auc:0.98984
# [420]	train-auc:0.99905	eval-auc:0.98984
# [421]	train-auc:0.99905	eval-auc:0.98984
# [422]	train-auc:0.99906	eval-auc:0.98987
# [423]	train-auc:0.99907	eval-auc:0.98988
# [424]	train-auc:0.99907	eval-auc:0.98988
# [425]	train-auc:0.99908	eval-auc:0.98987
# [426]	train-auc:0.99908	eval-auc:0.98987
# [427]	train-auc:0.99908	eval-auc:0.98987
# [428]	train-auc:0.99907	eval-auc:0.98984
# [429]	train-auc:0.99908	eval-auc:0.98984
# [430]	train-auc:0.99908	eval-auc:0.98984
# [431]	train-auc:0.99907	eval-auc:0.98987
# [432]	train-auc:0.99907	eval-auc:0.98987
# [433]	train-auc:0.99907	eval-auc:0.98987
# [434]	train-auc:0.99908	eval-auc:0.98987
# [435]	train-auc:0.99909	eval-auc:0.98980
# [436]	train-auc:0.99909	eval-auc:0.98985
# [437]	train-auc:0.99909	eval-auc:0.98985
# [438]	train-auc:0.99909	eval-auc:0.98985
# [439]	train-auc:0.99910	eval-auc:0.98992
# [440]	train-auc:0.99910	eval-auc:0.98991
# [441]	train-auc:0.99910	eval-auc:0.98991
# [442]	train-auc:0.99910	eval-auc:0.98991
# [443]	train-auc:0.99910	eval-auc:0.98991
# [444]	train-auc:0.99910	eval-auc:0.98991
# [445]	train-auc:0.99910	eval-auc:0.98991
# [446]	train-auc:0.99910	eval-auc:0.98991
# [447]	train-auc:0.99910	eval-auc:0.98991
# [448]	train-auc:0.99910	eval-auc:0.98991
# [449]	train-auc:0.99910	eval-auc:0.98991
# [450]	train-auc:0.99910	eval-auc:0.98991
# [451]	train-auc:0.99910	eval-auc:0.98991
# [452]	train-auc:0.99910	eval-auc:0.98991
# [453]	train-auc:0.99910	eval-auc:0.98991
# [454]	train-auc:0.99910	eval-auc:0.98991
# [455]	train-auc:0.99910	eval-auc:0.98991
# [456]	train-auc:0.99910	eval-auc:0.98991
# [457]	train-auc:0.99910	eval-auc:0.98990
# [458]	train-auc:0.99911	eval-auc:0.98992
# [459]	train-auc:0.99911	eval-auc:0.98992
# [460]	train-auc:0.99911	eval-auc:0.98992
# [461]	train-auc:0.99911	eval-auc:0.98992
# [462]	train-auc:0.99912	eval-auc:0.98985
# [463]	train-auc:0.99912	eval-auc:0.98985
# [464]	train-auc:0.99912	eval-auc:0.98985
# [465]	train-auc:0.99912	eval-auc:0.98985
# [466]	train-auc:0.99912	eval-auc:0.98985
# [467]	train-auc:0.99912	eval-auc:0.98985
# [468]	train-auc:0.99911	eval-auc:0.98985
# [469]	train-auc:0.99911	eval-auc:0.98985
# [470]	train-auc:0.99911	eval-auc:0.98985
# [471]	train-auc:0.99911	eval-auc:0.98985
# [472]	train-auc:0.99911	eval-auc:0.98985
# [473]	train-auc:0.99911	eval-auc:0.98985
# [474]	train-auc:0.99911	eval-auc:0.98985
# [475]	train-auc:0.99911	eval-auc:0.98988
# [476]	train-auc:0.99911	eval-auc:0.98988
# [477]	train-auc:0.99911	eval-auc:0.98988
# [478]	train-auc:0.99911	eval-auc:0.98988
# [479]	train-auc:0.99911	eval-auc:0.98988
# [480]	train-auc:0.99911	eval-auc:0.98988
# [481]	train-auc:0.99911	eval-auc:0.98988
# [482]	train-auc:0.99911	eval-auc:0.98988
# [483]	train-auc:0.99911	eval-auc:0.98982
# [484]	train-auc:0.99911	eval-auc:0.98981
# [485]	train-auc:0.99911	eval-auc:0.98981
# [486]	train-auc:0.99911	eval-auc:0.98981
# [487]	train-auc:0.99911	eval-auc:0.98981
# [488]	train-auc:0.99911	eval-auc:0.98981
# [489]	train-auc:0.99910	eval-auc:0.98983
# [490]	train-auc:0.99910	eval-auc:0.98983
# [491]	train-auc:0.99910	eval-auc:0.98983
# [492]	train-auc:0.99910	eval-auc:0.98983
# [493]	train-auc:0.99911	eval-auc:0.98988
# [494]	train-auc:0.99911	eval-auc:0.98983
# [495]	train-auc:0.99910	eval-auc:0.98980
# [496]	train-auc:0.99910	eval-auc:0.98980
# [497]	train-auc:0.99910	eval-auc:0.98980
# [498]	train-auc:0.99910	eval-auc:0.98980
# [499]	train-auc:0.99910	eval-auc:0.98980
# [0.9898035989717223]
# [0.9528795811518325]
# ************************************ 2 ************************************
# [0]	train-auc:0.97069	eval-auc:0.96689
# [1]	train-auc:0.97158	eval-auc:0.96764
# [2]	train-auc:0.97330	eval-auc:0.97260
# [3]	train-auc:0.97381	eval-auc:0.97335
# [4]	train-auc:0.97373	eval-auc:0.97322
# [5]	train-auc:0.97420	eval-auc:0.97434
# [6]	train-auc:0.97444	eval-auc:0.97436
# [7]	train-auc:0.97474	eval-auc:0.97481
# [8]	train-auc:0.97475	eval-auc:0.97451
# [9]	train-auc:0.97488	eval-auc:0.97447
# [10]	train-auc:0.98739	eval-auc:0.98635
# [11]	train-auc:0.98822	eval-auc:0.98692
# [12]	train-auc:0.98981	eval-auc:0.98837
# [13]	train-auc:0.98979	eval-auc:0.98837
# [14]	train-auc:0.99142	eval-auc:0.98884
# [15]	train-auc:0.99156	eval-auc:0.98900
# [16]	train-auc:0.99230	eval-auc:0.98865
# [17]	train-auc:0.99206	eval-auc:0.98822
# [18]	train-auc:0.99265	eval-auc:0.98933
# [19]	train-auc:0.99302	eval-auc:0.98912
# [20]	train-auc:0.99279	eval-auc:0.98920
# [21]	train-auc:0.99307	eval-auc:0.98903
# [22]	train-auc:0.99305	eval-auc:0.98882
# [23]	train-auc:0.99303	eval-auc:0.98896
# [24]	train-auc:0.99316	eval-auc:0.98929
# [25]	train-auc:0.99323	eval-auc:0.98945
# [26]	train-auc:0.99348	eval-auc:0.98962
# [27]	train-auc:0.99374	eval-auc:0.98962
# [28]	train-auc:0.99398	eval-auc:0.98991
# [29]	train-auc:0.99404	eval-auc:0.98968
# [30]	train-auc:0.99410	eval-auc:0.98968
# [31]	train-auc:0.99412	eval-auc:0.98973
# [32]	train-auc:0.99445	eval-auc:0.99021
# [33]	train-auc:0.99449	eval-auc:0.99046
# [34]	train-auc:0.99481	eval-auc:0.99033
# [35]	train-auc:0.99500	eval-auc:0.99051
# [36]	train-auc:0.99502	eval-auc:0.99054
# [37]	train-auc:0.99519	eval-auc:0.99083
# [38]	train-auc:0.99540	eval-auc:0.99089
# [39]	train-auc:0.99555	eval-auc:0.99087
# [40]	train-auc:0.99559	eval-auc:0.99103
# [41]	train-auc:0.99557	eval-auc:0.99097
# [42]	train-auc:0.99567	eval-auc:0.99100
# [43]	train-auc:0.99571	eval-auc:0.99097
# [44]	train-auc:0.99582	eval-auc:0.99074
# [45]	train-auc:0.99589	eval-auc:0.99065
# [46]	train-auc:0.99594	eval-auc:0.99061
# [47]	train-auc:0.99596	eval-auc:0.99039
# [48]	train-auc:0.99611	eval-auc:0.99034
# [49]	train-auc:0.99624	eval-auc:0.99054
# [50]	train-auc:0.99640	eval-auc:0.99055
# [51]	train-auc:0.99641	eval-auc:0.99046
# [52]	train-auc:0.99647	eval-auc:0.99055
# [53]	train-auc:0.99653	eval-auc:0.99078
# [54]	train-auc:0.99656	eval-auc:0.99083
# [55]	train-auc:0.99662	eval-auc:0.99089
# [56]	train-auc:0.99668	eval-auc:0.99071
# [57]	train-auc:0.99666	eval-auc:0.99089
# [58]	train-auc:0.99673	eval-auc:0.99097
# [59]	train-auc:0.99674	eval-auc:0.99104
# [60]	train-auc:0.99677	eval-auc:0.99113
# [61]	train-auc:0.99682	eval-auc:0.99106
# [62]	train-auc:0.99691	eval-auc:0.99115
# [481]	train-auc:0.99914	eval-auc:0.99102
# [482]	train-auc:0.99914	eval-auc:0.99102
# [483]	train-auc:0.99914	eval-auc:0.99102
# [484]	train-auc:0.99913	eval-auc:0.99104
# [485]	train-auc:0.99913	eval-auc:0.99104
# [486]	train-auc:0.99913	eval-auc:0.99104
# [487]	train-auc:0.99913	eval-auc:0.99104
# [488]	train-auc:0.99914	eval-auc:0.99106
# [489]	train-auc:0.99914	eval-auc:0.99106
# [490]	train-auc:0.99914	eval-auc:0.99105
# [491]	train-auc:0.99914	eval-auc:0.99105
# [492]	train-auc:0.99914	eval-auc:0.99105
# [493]	train-auc:0.99915	eval-auc:0.99099
# [494]	train-auc:0.99915	eval-auc:0.99102
# [495]	train-auc:0.99915	eval-auc:0.99102
# [496]	train-auc:0.99915	eval-auc:0.99104
# [497]	train-auc:0.99915	eval-auc:0.99105
# [498]	train-auc:0.99917	eval-auc:0.99101
# [499]	train-auc:0.99917	eval-auc:0.99101
# [0.9898035989717223, 0.99100689746213]
# [0.9528795811518325, 0.9370988446726572]
# ************************************ 3 ************************************
# [0]	train-auc:0.96675	eval-auc:0.96677
# [1]	train-auc:0.97075	eval-auc:0.96766
# [2]	train-auc:0.97131	eval-auc:0.96757
# [3]	train-auc:0.97146	eval-auc:0.96790
# [4]	train-auc:0.97333	eval-auc:0.96962
# [5]	train-auc:0.97389	eval-auc:0.96955
# [6]	train-auc:0.97488	eval-auc:0.97267
# [7]	train-auc:0.97466	eval-auc:0.97225
# [8]	train-auc:0.97458	eval-auc:0.97214
# [9]	train-auc:0.97472	eval-auc:0.97210
# [10]	train-auc:0.98700	eval-auc:0.98334
# [11]	train-auc:0.98721	eval-auc:0.98370
# [12]	train-auc:0.98849	eval-auc:0.98413
# [13]	train-auc:0.98948	eval-auc:0.98519
# [14]	train-auc:0.99073	eval-auc:0.98588
# [15]	train-auc:0.99103	eval-auc:0.98570
# [16]	train-auc:0.99116	eval-auc:0.98586
# [17]	train-auc:0.99134	eval-auc:0.98606
# [18]	train-auc:0.99170	eval-auc:0.98638
# [19]	train-auc:0.99210	eval-auc:0.98576
# [20]	train-auc:0.99256	eval-auc:0.98622
# [21]	train-auc:0.99274	eval-auc:0.98620
# [22]	train-auc:0.99285	eval-auc:0.98626
# [23]	train-auc:0.99291	eval-auc:0.98612
# [24]	train-auc:0.99290	eval-auc:0.98622
# [25]	train-auc:0.99319	eval-auc:0.98674
# [26]	train-auc:0.99351	eval-auc:0.98682
# [27]	train-auc:0.99352	eval-auc:0.98659
# [28]	train-auc:0.99389	eval-auc:0.98729
# [29]	train-auc:0.99396	eval-auc:0.98765
# [30]	train-auc:0.99400	eval-auc:0.98791
# [31]	train-auc:0.99432	eval-auc:0.98808
# [32]	train-auc:0.99439	eval-auc:0.98796
# [33]	train-auc:0.99455	eval-auc:0.98808
# [34]	train-auc:0.99471	eval-auc:0.98815
# [35]	train-auc:0.99491	eval-auc:0.98829
# [36]	train-auc:0.99507	eval-auc:0.98848
# [37]	train-auc:0.99515	eval-auc:0.98857
# [38]	train-auc:0.99522	eval-auc:0.98830
# [39]	train-auc:0.99531	eval-auc:0.98827
# [40]	train-auc:0.99549	eval-auc:0.98829
# [41]	train-auc:0.99550	eval-auc:0.98836
# [42]	train-auc:0.99562	eval-auc:0.98864
# [43]	train-auc:0.99567	eval-auc:0.98872
# [44]	train-auc:0.99572	eval-auc:0.98876
# [45]	train-auc:0.99579	eval-auc:0.98872
# [46]	train-auc:0.99580	eval-auc:0.98865
# [47]	train-auc:0.99588	eval-auc:0.98866
# [48]	train-auc:0.99602	eval-auc:0.98841
# [49]	train-auc:0.99610	eval-auc:0.98826
# [50]	train-auc:0.99622	eval-auc:0.98809
# [51]	train-auc:0.99632	eval-auc:0.98794
# [52]	train-auc:0.99639	eval-auc:0.98768
# [53]	train-auc:0.99641	eval-auc:0.98783
# [54]	train-auc:0.99640	eval-auc:0.98789
# [55]	train-auc:0.99651	eval-auc:0.98799
# [56]	train-auc:0.99656	eval-auc:0.98805
# [57]	train-auc:0.99662	eval-auc:0.98777
# [58]	train-auc:0.99664	eval-auc:0.98792
# [59]	train-auc:0.99671	eval-auc:0.98793
# [60]	train-auc:0.99679	eval-auc:0.98769
# [61]	train-auc:0.99676	eval-auc:0.98741
# [62]	train-auc:0.99686	eval-auc:0.98743
# [63]	train-auc:0.99684	eval-auc:0.98721
# [64]	train-auc:0.99685	eval-auc:0.98715
# [65]	train-auc:0.99687	eval-auc:0.98718
# [66]	train-auc:0.99696	eval-auc:0.98740
# [67]	train-auc:0.99696	eval-auc:0.98737
# [68]	train-auc:0.99698	eval-auc:0.98729
# [69]	train-auc:0.99706	eval-auc:0.98734
# [70]	train-auc:0.99709	eval-auc:0.98705
# [71]	train-auc:0.99711	eval-auc:0.98706
# [72]	train-auc:0.99714	eval-auc:0.98715
# [73]	train-auc:0.99713	eval-auc:0.98705
# [74]	train-auc:0.99721	eval-auc:0.98696
# [75]	train-auc:0.99722	eval-auc:0.98701
# [76]	train-auc:0.99728	eval-auc:0.98703
# [77]	train-auc:0.99728	eval-auc:0.98708
# [78]	train-auc:0.99728	eval-auc:0.98706
# [79]	train-auc:0.99733	eval-auc:0.98695
# [80]	train-auc:0.99731	eval-auc:0.98678
# [81]	train-auc:0.99732	eval-auc:0.98696
# [82]	train-auc:0.99739	eval-auc:0.98703
# [83]	train-auc:0.99739	eval-auc:0.98703
# [84]	train-auc:0.99741	eval-auc:0.98696
# [85]	train-auc:0.99739	eval-auc:0.98675
# [86]	train-auc:0.99742	eval-auc:0.98669
# [87]	train-auc:0.99741	eval-auc:0.98701
# [88]	train-auc:0.99749	eval-auc:0.98718
# [89]	train-auc:0.99754	eval-auc:0.98718
# [90]	train-auc:0.99757	eval-auc:0.98732
# [91]	train-auc:0.99759	eval-auc:0.98732
# [92]	train-auc:0.99759	eval-auc:0.98732
# [93]	train-auc:0.99759	eval-auc:0.98732
# [94]	train-auc:0.99761	eval-auc:0.98743
# [95]	train-auc:0.99761	eval-auc:0.98746
# [96]	train-auc:0.99762	eval-auc:0.98749
# [97]	train-auc:0.99766	eval-auc:0.98724
# [98]	train-auc:0.99770	eval-auc:0.98739
# [99]	train-auc:0.99769	eval-auc:0.98740
# [100]	train-auc:0.99772	eval-auc:0.98744
# [101]	train-auc:0.99772	eval-auc:0.98741
# [102]	train-auc:0.99772	eval-auc:0.98741
# [103]	train-auc:0.99772	eval-auc:0.98734
# [104]	train-auc:0.99774	eval-auc:0.98734
# [105]	train-auc:0.99774	eval-auc:0.98734
# [106]	train-auc:0.99778	eval-auc:0.98739
# [107]	train-auc:0.99787	eval-auc:0.98731
# [108]	train-auc:0.99789	eval-auc:0.98720
# [109]	train-auc:0.99789	eval-auc:0.98727
# [110]	train-auc:0.99793	eval-auc:0.98722
# [111]	train-auc:0.99793	eval-auc:0.98722
# [112]	train-auc:0.99792	eval-auc:0.98735
# [113]	train-auc:0.99792	eval-auc:0.98735
# [114]	train-auc:0.99792	eval-auc:0.98735
# [115]	train-auc:0.99792	eval-auc:0.98735
# [116]	train-auc:0.99797	eval-auc:0.98757
# [117]	train-auc:0.99798	eval-auc:0.98757
# [118]	train-auc:0.99798	eval-auc:0.98757
# [119]	train-auc:0.99799	eval-auc:0.98764
# [120]	train-auc:0.99799	eval-auc:0.98771
# [121]	train-auc:0.99800	eval-auc:0.98768
# [122]	train-auc:0.99800	eval-auc:0.98768
# [123]	train-auc:0.99802	eval-auc:0.98763
# [124]	train-auc:0.99800	eval-auc:0.98767
# [125]	train-auc:0.99800	eval-auc:0.98768
# [126]	train-auc:0.99800	eval-auc:0.98768
# [127]	train-auc:0.99800	eval-auc:0.98768
# [128]	train-auc:0.99800	eval-auc:0.98768
# [129]	train-auc:0.99805	eval-auc:0.98775
# [130]	train-auc:0.99807	eval-auc:0.98748
# [131]	train-auc:0.99808	eval-auc:0.98754
# [132]	train-auc:0.99810	eval-auc:0.98754
# [133]	train-auc:0.99810	eval-auc:0.98754
# [134]	train-auc:0.99810	eval-auc:0.98754
# [135]	train-auc:0.99809	eval-auc:0.98755
# [136]	train-auc:0.99809	eval-auc:0.98755
# [137]	train-auc:0.99811	eval-auc:0.98749
# [138]	train-auc:0.99811	eval-auc:0.98749
# [139]	train-auc:0.99809	eval-auc:0.98766
# [140]	train-auc:0.99810	eval-auc:0.98771
# [141]	train-auc:0.99811	eval-auc:0.98765
# [142]	train-auc:0.99813	eval-auc:0.98772
# [143]	train-auc:0.99814	eval-auc:0.98769
# [144]	train-auc:0.99814	eval-auc:0.98769
# [145]	train-auc:0.99814	eval-auc:0.98768
# [146]	train-auc:0.99818	eval-auc:0.98774
# [147]	train-auc:0.99820	eval-auc:0.98761
# [148]	train-auc:0.99820	eval-auc:0.98761
# [149]	train-auc:0.99822	eval-auc:0.98763
# [150]	train-auc:0.99822	eval-auc:0.98759
# [151]	train-auc:0.99822	eval-auc:0.98759
# [152]	train-auc:0.99822	eval-auc:0.98759
# [153]	train-auc:0.99822	eval-auc:0.98756
# [154]	train-auc:0.99825	eval-auc:0.98762
# [155]	train-auc:0.99825	eval-auc:0.98762
# [156]	train-auc:0.99825	eval-auc:0.98757
# [157]	train-auc:0.99825	eval-auc:0.98757
# [158]	train-auc:0.99825	eval-auc:0.98750
# [159]	train-auc:0.99825	eval-auc:0.98752
# [160]	train-auc:0.99825	eval-auc:0.98747
# [161]	train-auc:0.99830	eval-auc:0.98764
# [162]	train-auc:0.99829	eval-auc:0.98764
# [163]	train-auc:0.99831	eval-auc:0.98768
# [164]	train-auc:0.99832	eval-auc:0.98762
# [165]	train-auc:0.99833	eval-auc:0.98765
# [166]	train-auc:0.99832	eval-auc:0.98764
# [167]	train-auc:0.99833	eval-auc:0.98767
# [168]	train-auc:0.99837	eval-auc:0.98778
# [169]	train-auc:0.99838	eval-auc:0.98765
# ...
# [125]	train-auc:0.99783	eval-auc:0.99333
# [126]	train-auc:0.99786	eval-auc:0.99336
# [127]	train-auc:0.99791	eval-auc:0.99332
# [128]	train-auc:0.99794	eval-auc:0.99332
# [129]	train-auc:0.99794	eval-auc:0.99332
# [130]	train-auc:0.99796	eval-auc:0.99329
# [131]	train-auc:0.99796	eval-auc:0.99329
# [132]	train-auc:0.99797	eval-auc:0.99329
# [133]	train-auc:0.99799	eval-auc:0.99335
# [134]	train-auc:0.99800	eval-auc:0.99334
# [135]	train-auc:0.99800	eval-auc:0.99320
# [136]	train-auc:0.99802	eval-auc:0.99319
# [137]	train-auc:0.99802	eval-auc:0.99319
# [138]	train-auc:0.99801	eval-auc:0.99318
# [139]	train-auc:0.99803	eval-auc:0.99319
# [140]	train-auc:0.99803	eval-auc:0.99319
# [141]	train-auc:0.99803	eval-auc:0.99319
# [142]	train-auc:0.99803	eval-auc:0.99324
# [143]	train-auc:0.99807	eval-auc:0.99321
# [144]	train-auc:0.99808	eval-auc:0.99319
# [145]	train-auc:0.99808	eval-auc:0.99319
# [146]	train-auc:0.99809	eval-auc:0.99320
# [147]	train-auc:0.99812	eval-auc:0.99307
# [148]	train-auc:0.99812	eval-auc:0.99307
# [149]	train-auc:0.99813	eval-auc:0.99300
# [150]	train-auc:0.99813	eval-auc:0.99300
# [151]	train-auc:0.99813	eval-auc:0.99304
# [152]	train-auc:0.99813	eval-auc:0.99303
# [153]	train-auc:0.99816	eval-auc:0.99305
# [154]	train-auc:0.99821	eval-auc:0.99306
# [155]	train-auc:0.99821	eval-auc:0.99306
# [156]	train-auc:0.99821	eval-auc:0.99306
# [157]	train-auc:0.99821	eval-auc:0.99306
# [158]	train-auc:0.99821	eval-auc:0.99307
# [159]	train-auc:0.99822	eval-auc:0.99309
# [160]	train-auc:0.99822	eval-auc:0.99309
# [161]	train-auc:0.99823	eval-auc:0.99309
# [162]	train-auc:0.99823	eval-auc:0.99314
# [163]	train-auc:0.99824	eval-auc:0.99312
# [164]	train-auc:0.99825	eval-auc:0.99318
# [165]	train-auc:0.99825	eval-auc:0.99318
# [166]	train-auc:0.99829	eval-auc:0.99306
# [167]	train-auc:0.99829	eval-auc:0.99306
# [168]	train-auc:0.99829	eval-auc:0.99306
# [169]	train-auc:0.99829	eval-auc:0.99306
# [170]	train-auc:0.99829	eval-auc:0.99306
# [171]	train-auc:0.99831	eval-auc:0.99311
# [172]	train-auc:0.99831	eval-auc:0.99311
# [412]	train-auc:0.99900	eval-auc:0.99313
# [413]	train-auc:0.99900	eval-auc:0.99311
# [414]	train-auc:0.99900	eval-auc:0.99311
# [415]	train-auc:0.99900	eval-auc:0.99311
# [416]	train-auc:0.99899	eval-auc:0.99319
# [417]	train-auc:0.99899	eval-auc:0.99319
# [418]	train-auc:0.99900	eval-auc:0.99315
# [419]	train-auc:0.99901	eval-auc:0.99313
# [420]	train-auc:0.99901	eval-auc:0.99313
# [421]	train-auc:0.99901	eval-auc:0.99313
# [422]	train-auc:0.99902	eval-auc:0.99315
# [423]	train-auc:0.99902	eval-auc:0.99315
# [424]	train-auc:0.99902	eval-auc:0.99315
# [425]	train-auc:0.99902	eval-auc:0.99320
# [426]	train-auc:0.99902	eval-auc:0.99320
# [427]	train-auc:0.99903	eval-auc:0.99318
# [428]	train-auc:0.99902	eval-auc:0.99317
# [429]	train-auc:0.99903	eval-auc:0.99317
# [430]	train-auc:0.99903	eval-auc:0.99321
# [431]	train-auc:0.99903	eval-auc:0.99321
# [432]	train-auc:0.99903	eval-auc:0.99321
# [433]	train-auc:0.99903	eval-auc:0.99321
# [434]	train-auc:0.99904	eval-auc:0.99322
# [435]	train-auc:0.99904	eval-auc:0.99322
# [436]	train-auc:0.99904	eval-auc:0.99322
# [437]	train-auc:0.99904	eval-auc:0.99322
# [438]	train-auc:0.99904	eval-auc:0.99322
# [439]	train-auc:0.99904	eval-auc:0.99322
# [440]	train-auc:0.99904	eval-auc:0.99322
# [441]	train-auc:0.99905	eval-auc:0.99319
# [442]	train-auc:0.99905	eval-auc:0.99319
# [443]	train-auc:0.99905	eval-auc:0.99319
# [444]	train-auc:0.99905	eval-auc:0.99313
# [445]	train-auc:0.99905	eval-auc:0.99312
# [446]	train-auc:0.99906	eval-auc:0.99316
# [447]	train-auc:0.99906	eval-auc:0.99316
# [448]	train-auc:0.99906	eval-auc:0.99309
# [449]	train-auc:0.99906	eval-auc:0.99309
# [450]	train-auc:0.99906	eval-auc:0.99309
# [451]	train-auc:0.99906	eval-auc:0.99309
# [452]	train-auc:0.99906	eval-auc:0.99309
# [453]	train-auc:0.99906	eval-auc:0.99309
# [454]	train-auc:0.99906	eval-auc:0.99309
# [455]	train-auc:0.99906	eval-auc:0.99309
# [456]	train-auc:0.99907	eval-auc:0.99310
# [457]	train-auc:0.99907	eval-auc:0.99310
# [458]	train-auc:0.99908	eval-auc:0.99311
# [459]	train-auc:0.99908	eval-auc:0.99311
# [460]	train-auc:0.99908	eval-auc:0.99311
# [461]	train-auc:0.99908	eval-auc:0.99317
# [462]	train-auc:0.99908	eval-auc:0.99316
# [463]	train-auc:0.99908	eval-auc:0.99314
# [464]	train-auc:0.99908	eval-auc:0.99312
# [465]	train-auc:0.99908	eval-auc:0.99312
# [466]	train-auc:0.99908	eval-auc:0.99312
# [467]	train-auc:0.99908	eval-auc:0.99311
# [468]	train-auc:0.99908	eval-auc:0.99311
# [469]	train-auc:0.99908	eval-auc:0.99311
# [470]	train-auc:0.99909	eval-auc:0.99312
# [471]	train-auc:0.99909	eval-auc:0.99312
# [472]	train-auc:0.99909	eval-auc:0.99312
# [473]	train-auc:0.99909	eval-auc:0.99310
# [474]	train-auc:0.99909	eval-auc:0.99310
# [475]	train-auc:0.99909	eval-auc:0.99310
# [476]	train-auc:0.99909	eval-auc:0.99310
# [477]	train-auc:0.99909	eval-auc:0.99310
# [478]	train-auc:0.99909	eval-auc:0.99309
# [479]	train-auc:0.99909	eval-auc:0.99309
# [480]	train-auc:0.99909	eval-auc:0.99309
# [481]	train-auc:0.99909	eval-auc:0.99309
# [482]	train-auc:0.99909	eval-auc:0.99309
# [483]	train-auc:0.99909	eval-auc:0.99305
# [484]	train-auc:0.99909	eval-auc:0.99305
# [485]	train-auc:0.99909	eval-auc:0.99309
# [486]	train-auc:0.99909	eval-auc:0.99307
# [487]	train-auc:0.99909	eval-auc:0.99307
# [488]	train-auc:0.99909	eval-auc:0.99307
# [489]	train-auc:0.99909	eval-auc:0.99307
# [490]	train-auc:0.99909	eval-auc:0.99307
# [491]	train-auc:0.99909	eval-auc:0.99307
# [492]	train-auc:0.99909	eval-auc:0.99307
# [493]	train-auc:0.99909	eval-auc:0.99319
# [494]	train-auc:0.99909	eval-auc:0.99319
# [495]	train-auc:0.99909	eval-auc:0.99319
# [496]	train-auc:0.99909	eval-auc:0.99319
# [497]	train-auc:0.99909	eval-auc:0.99319
# [498]	train-auc:0.99909	eval-auc:0.99319
# [499]	train-auc:0.99910	eval-auc:0.99318
# [0.9898035989717223, 0.99100689746213, 0.9875870083948419, 0.9825686375321336, 0.9931782049429108]
# [0.9528795811518325, 0.9370988446726572, 0.9302325581395349, 0.9258312020460359, 0.9494163424124514]
# xgb_scotrainre_list: [0.9898035989717223, 0.99100689746213, 0.9875870083948419, 0.9825686375321336, 0.9931782049429108]
# xgb_score_mean: 0.9888288694607477
# xgb_score_std: 0.003615061422377892
# xgb f1_scotrainre_list: [0.9528795811518325, 0.9370988446726572, 0.9302325581395349, 0.9258312020460359, 0.9494163424124514]
# xgb f1_score_mean: 0.9390917056845023
# xgb f1_score_std: 0.010535659262225001

# %%
filename = save_variable(xgb_train,'process_variable(reserve)/xgb_train')
filename = save_variable(xgb_test,'process_variable(reserve)/xgb_test')

# %%
xgb_train = load_variavle('process_variable(reserve)/xgb_train')
xgb_test = load_variavle('process_variable(reserve)/xgb_test')

# %%
input_train1 = [xgb_train, lgb_train] 
input_test1 = [xgb_test, lgb_test]
stacked_train1 = np.concatenate([f.reshape(-1, 1) for f in input_train1], axis=1)
stacked_test1 = np.concatenate([f.reshape(-1, 1) for f in input_test1], axis=1)

# %%
final_model1 = LinearRegression()
final_model1.fit(stacked_train1, train_label)
test_prediction1 = final_model1.predict(stacked_test1)

# %%
pre_y=pd.DataFrame(lgb_test)
pre_y['label']=pre_y[0].apply(lambda x:1 if x>0.5 else 0)
result=pd.read_csv('提交示例.csv')
result['label']=pre_y['label']
result.to_csv('暂存数据(备用)/特征衍生_xgb_lgb.csv',index=False)

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/reh7ykwic8.jpg?imageView2/0/w/960/h/960)
